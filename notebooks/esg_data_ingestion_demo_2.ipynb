# %% [markdown]
# # Setup

# %%
# two possible apis to generate a trino connection:
import trino
# from pyhive import presto

# pandas dfs
import pandas as pd

import urllib3
urllib3.disable_warnings()
# Out:
# /var/folders/gp/7f5d9bz54rgg8x8hbqxjrr2h0000gn/T/ipykernel_44574/3754470294.py:6: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
from dotenv import dotenv_values, load_dotenv
import os
import pathlib

dotenv_path = '../credentials.env'
if os.path.exists(dotenv_path):
    load_dotenv(dotenv_path=dotenv_path,override=True)

# %%
JWT_TOKEN = os.environ['TRINO_PASSWD']
conn = trino.dbapi.connect(
    host=os.environ['TRINO_HOST'],
    port=int(os.environ['TRINO_PORT']),
    user=os.environ['TRINO_USER'],
    http_scheme='https',
    auth=trino.auth.JWTAuthentication(JWT_TOKEN),
    verify=True,
)
cur = conn.cursor()

# %% [markdown]
# # Get Catalogs

# %%
cur.execute('show catalogs')
all_catalogs = cur.fetchall()
all_catalogs
# Out:
# [['jmx'],
#  ['kafka_fx'],
#  ['kafka_osclimate'],
#  ['oef_openclimate'],
#  ['osc_datacommons_dev'],
#  ['osc_datacommons_hive_ingest'],
#  ['system'],
#  ['uwm_prometheus']]

# %% [markdown]
# # Get Schemas for each Catalog

# %%
import traceback

# Assuming all_catalogs is a list of tuples, with each tuple containing at least one element: the catalog name.
all_data = []

for catalog in all_catalogs:
    catalog_name = catalog[0]
    print(catalog_name)
    try:
        cur.execute(f'SHOW SCHEMAS IN {catalog_name}')
        cur_schemas = cur.fetchall()
        catalog_data = {'catalog': catalog_name, 'schemas': []}
        
        for schema in cur_schemas:
            schema_name = schema[0]
            try:
                cur.execute(f'SHOW TABLES IN {catalog_name}.{schema_name}')
                cur_tables = cur.fetchall()
                # Flatten the list of tuples to a list of table names
                tables_list = [table[0] for table in cur_tables]
                schema_data = {'schema': schema_name, 'tables': tables_list}
                catalog_data['schemas'].append(schema_data)
            except Exception as e:
                print(f'Error fetching tables for schema {schema_name} in catalog {catalog_name}: {e}')
                traceback.print_exc()
                # Optionally append a schema with an error note, or pass to ignore
                # catalog_data['schemas'].append({'schema': schema_name, 'error': 'Failed to fetch tables'})

        all_data.append(catalog_data)
    except Exception as e:
        print(f'Error with catalog {catalog_name}: {e}')
        traceback.print_exc()
        # Optionally keep the catalog with an error note, or pass to ignore
        # all_data.append({'catalog': catalog_name, 'error': 'Failed to fetch schemas'})

# Now all_data contains all the information
all_data
# Out:
# jmx
# kafka_fx
# Error fetching tables for schema ecb-fx in catalog kafka_fx: TrinoUserError(type=USER_ERROR, name=SYNTAX_ERROR, message="line 1:28: mismatched input '-'. Expecting: '.', 'LIKE', <EOF>", query_id=20240404_185929_00389_xvsm6)
# Traceback (most recent call last):
#   File "/var/folders/gp/7f5d9bz54rgg8x8hbqxjrr2h0000gn/T/ipykernel_44574/24418238.py", line 17, in <module>
#     cur.execute(f'SHOW TABLES IN {catalog_name}.{schema_name}')
#   File "/Users/lucasgoh/.julia/conda/3/aarch64/lib/python3.10/site-packages/trino/dbapi.py", line 589, in execute
#     self._iterator = iter(self._query.execute())
#   File "/Users/lucasgoh/.julia/conda/3/aarch64/lib/python3.10/site-packages/trino/client.py", line 797, in execute
#     self._result.rows += self.fetch()
#   File "/Users/lucasgoh/.julia/conda/3/aarch64/lib/python3.10/site-packages/trino/client.py", line 817, in fetch
#     status = self._request.process(response)
#   File "/Users/lucasgoh/.julia/conda/3/aarch64/lib/python3.10/site-packages/trino/client.py", line 595, in process
#     raise self._process_error(response["error"], response.get("id"))
# trino.exceptions.TrinoUserError: TrinoUserError(type=USER_ERROR, name=SYNTAX_ERROR, message="line 1:28: mismatched input '-'. Expecting: '.', 'LIKE', <EOF>", query_id=20240404_185929_00389_xvsm6)
# kafka_osclimate
# oef_openclimate
# Error with catalog oef_openclimate: TrinoExternalError(type=EXTERNAL, name=JDBC_ERROR, message="Error listing schemas for catalog oef_openclimate: Could not open SSL root certificate file //.postgresql/root.crt.", query_id=20240404_185930_00396_xvsm6)
# osc_datacommons_dev
# Traceback (most recent call last):
#   File "/var/folders/gp/7f5d9bz54rgg8x8hbqxjrr2h0000gn/T/ipykernel_44574/24418238.py", line 10, in <module>
#     cur.execute(f'SHOW SCHEMAS IN {catalog_name}')
#   File "/Users/lucasgoh/.julia/conda/3/aarch64/lib/python3.10/site-packages/trino/dbapi.py", line 589, in execute
#     self._iterator = iter(self._query.execute())
#   File "/Users/lucasgoh/.julia/conda/3/aarch64/lib/python3.10/site-packages/trino/client.py", line 797, in execute
#     self._result.rows += self.fetch()
#   File "/Users/lucasgoh/.julia/conda/3/aarch64/lib/python3.10/site-packages/trino/client.py", line 817, in fetch
#     status = self._request.process(response)
#   File "/Users/lucasgoh/.julia/conda/3/aarch64/lib/python3.10/site-packages/trino/client.py", line 595, in process
#     raise self._process_error(response["error"], response.get("id"))
#   File "/Users/lucasgoh/.julia/conda/3/aarch64/lib/python3.10/site-packages/trino/client.py", line 565, in _process_error
#     raise exceptions.TrinoExternalError(error, query_id)
# trino.exceptions.TrinoExternalError: TrinoExternalError(type=EXTERNAL, name=JDBC_ERROR, message="Error listing schemas for catalog oef_openclimate: Could not open SSL root certificate file //.postgresql/root.crt.", query_id=20240404_185930_00396_xvsm6)
# osc_datacommons_hive_ingest
# system
# uwm_prometheus
# [{'catalog': 'jmx',
#   'schemas': [{'schema': 'current', 'tables': []},
#    {'schema': 'history', 'tables': []},
#    {'schema': 'information_schema',
#     'tables': ['applicable_roles',
#      'columns',
#      'enabled_roles',
#      'roles',
#      'schemata',
#      'table_privileges',
#      'tables',
#      'views']}]},
#  {'catalog': 'kafka_fx',
#   'schemas': [{'schema': 'information_schema',
#     'tables': ['applicable_roles',
#      'columns',
#      'enabled_roles',
#      'roles',
#      'schemata',
#      'table_privileges',
#      'tables',
#      'views']},
#    {'schema': 'kepler', 'tables': []},
#    {'schema': 'tpch', 'tables': []}]},
#  {'catalog': 'kafka_osclimate',
#   'schemas': [{'schema': 'electricitymap', 'tables': []},
#    {'schema': 'information_schema',
#     'tables': ['applicable_roles',
#      'columns',
#      'enabled_roles',
#      'roles',
#      'schemata',
#      'table_privileges',
#      'tables',
#      'views']}]},
#  {'catalog': 'osc_datacommons_dev',
#   'schemas': [{'schema': 'aicoe_osc_demo_results', 'tables': ['infer_kpi']},
#    {'schema': 'default', 'tables': []},
#    {'schema': 'demo_dv',
#     'tables': ['itr_benchmark_ei',
#      'itr_benchmark_prod',
#      'itr_company_data',
#      'itr_cumulative_budgets',
#      'itr_cumulative_emissions',
#      'itr_overshoot_ratios',
#      'itr_production_data',
#      'itr_target_data',
#      'itr_temperature_scores',
#      'itr_trajectory_data']},
#    {'schema': 'dera',
#     'tables': ['assets_usd_by_lei',
#      'assets_xyz_by_lei',
#      'average_fx',
#      'cash_usd_by_lei',
#      'cash_xyz_by_lei',
#      'closing_fx',
#      'debt_usd_by_lei',
#      'debt_xyz_by_lei',
#      'dera_num',
#      'dera_num_source',
#      'dera_sub',
#      'dera_sub_source',
#      'dera_tag',
#      'dera_tag_source',
#      'financials_by_lei',
#      'float_usd_by_lei',
#      'float_xyz_by_lei',
#      'fy_income_usd_by_lei',
#      'fy_income_xyz_by_lei',
#      'fy_revenue_usd_by_lei',
#      'fy_revenue_xyz_by_lei',
#      'sic_isic',
#      't_a',
#      't_c',
#      't_d',
#      't_f',
#      't_i',
#      't_r',
#      'ticker',
#      'ticker_source']},
#    {'schema': 'essd',
#     'tables': ['ch4_gwp',
#      'ch4_gwp_source',
#      'ghg_data',
#      'ghg_data_source',
#      'gwp100_data',
#      'gwp100_data_source',
#      'gwp_100yr',
#      'gwp_100yr_source',
#      'lulucf',
#      'lulucf_source',
#      'regions',
#      'regions_source',
#      'sectors',
#      'sectors_source']},
#    {'schema': 'iceberg_demo', 'tables': []},
#    {'schema': 'information_schema',
#     'tables': ['applicable_roles',
#      'columns',
#      'enabled_roles',
#      'roles',
#      'schemata',
#      'table_privileges',
#      'tables',
#      'views']},
#    {'schema': 'ingest',
#     'tables': ['ingest_temp_075f3fba',
#      'ingest_temp_4d5d42df',
#      'ingest_temp_73658d7e',
#      'ingest_temp_776aeb7c',
#      'ingest_temp_9fcb2c78',
#      'ingest_temp_d258c4a0']},
#    {'schema': 'mdt_sandbox',
#     'tables': ['countries',
#      'isic_to_sector',
#      'itr_portfolio_universe',
#      'pcaf_dbt_models',
#      'portfolio_universe',
#      'saved_queries',
#      'sf_oecd_exch_rates',
#      'sf_oecd_exch_rates_source',
#      'sf_oecd_exgr_dco2',
#      'sf_oecd_exgr_dco2_source',
#      'sf_oecd_imgr_fco2',
#      'sf_oecd_imgr_fco2_source',
#      'sf_primap_hist_emissions',
#      'sf_primap_hist_emissions_source',
#      'sf_total_sovereign_emissions',
#      'sf_total_sovereign_emissions_source',
#      'sf_unfccc_countries_source',
#      'sf_unfccc_results',
#      'sf_unfccc_results_source',
#      'sf_unfccc_with_lulucf',
#      'sf_unfccc_with_lulucf_source',
#      'sf_unfccc_without_lulucf',
#      'sf_unfccc_without_lulucf_source',
#      'sf_wdi_gdp',
#      'sf_wdi_gdp_source',
#      'sf_wdi_population',
#      'sf_wdi_population_source',
#      'subdivisions']},
#    {'schema': 'pcaf_sovereign_footprint',
#     'tables': ['oecd_co2_emissions',
#      'population_source',
#      'sf_oecd_exch_rates',
#      'sf_oecd_exgr_dco2',
#      'sf_oecd_imgr_fco2',
#      'sf_primap_emissions_with_lulucf',
#      'sf_primap_emissions_without_lulucf',
#      'sf_total_sovereign_emissions',
#      'sf_unfccc_countries',
#      'sf_unfccc_results',
#      'sf_unfccc_with_lulucf',
#      'sf_unfccc_without_lulucf',
#      'sf_wdi_gdp',
#      'sf_wdi_population']},
#    {'schema': 'rmi',
#     'tables': ['assets_earnings_investments',
#      'assets_earnings_investments_source',
#      'customers_sales',
#      'customers_sales_source',
#      'debt_equity_returns',
#      'debt_equity_returns_source',
#      'emissions_targets',
#      'emissions_targets_source',
#      'employees',
#      'employees_source',
#      'expenditure_bills_burden',
#      'expenditure_bills_burden_source',
#      'housing_units_income',
#      'housing_units_income_source',
#      'net_plant_balance',
#      'net_plant_balance_source',
#      'operations_emissions_by_fuel',
#      'operations_emissions_by_fuel_source',
#      'operations_emissions_by_tech',
#      'operations_emissions_by_tech_source',
#      'revenue_by_tech',
#      'revenue_by_tech_source',
#      'state_policies',
#      'state_policies_source',
#      'state_targets',
#      'state_targets_source',
#      'utility_information',
#      'utility_information_2023',
#      'utility_information_2023_source',
#      'utility_information_source',
#      'utility_state_map',
#      'utility_state_map_2023',
#      'utility_state_map_2023_source',
#      'utility_state_map_source']},
#    {'schema': 'sandbox',
#     'tables': ['assets_earnings_investments',
#      'assets_usd_by_lei',
#      'assets_xyz_by_lei',
#      'average_fx',
#      'cash_usd_by_lei',
#      'cash_xyz_by_lei',
#      'census_all_sector_survey_2017',
#      'census_sic4',
#      'census_sic_ranges',
#      'climactor_demo',
#      'closing_fx',
#      'countries',
#      'customers_sales',
#      'dashboard_carbon_intensity',
#      'dashboard_carbon_monitoring',
#      'dashboard_pod_energy',
#      'debt_equity_returns',
#      'debt_usd_by_lei',
#      'debt_xyz_by_lei',
#      'dera_num',
#      'dera_sub',
#      'dera_tag',
#      'emissions_targets',
#      'employees',
#      'epa_co2_injection',
#      'epa_direct_emitters',
#      'epa_gathering_boosting',
#      'epa_geologic_sequestration_of_co2',
#      'epa_ldc_direct_emissions',
#      'epa_onshore_oil_gas_prod',
#      'epa_parent_attribution',
#      'epa_parent_company',
#      'epa_sankey',
#      'epa_sf6_from_elec_equip',
#      'epa_suppliers',
#      'epa_transmission_pipelines',
#      'essd_ch4_gwp',
#      'essd_ghg_data',
#      'essd_gwp100_data',
#      'essd_gwp_100yr',
#      'essd_lulucf',
#      'essd_regions',
#      'essd_sectors',
#      'expenditure_bills_burden',
#      'financials_by_lei',
#      'float_usd_by_lei',
#      'float_xyz_by_lei',
#      'fy_income_usd_by_lei',
#      'fy_income_xyz_by_lei',
#      'fy_revenue_usd_by_lei',
#      'fy_revenue_xyz_by_lei',
#      'gleif_direct_issuer_ultimate_issuer',
#      'gleif_isin_lei',
#      'gppd_plants',
#      'gppd_plants_list',
#      'gppd_power_plants_list',
#      'gppd_pp_list',
#      'gppd_source',
#      'housing_units_income',
#      'iceberg_demo_erikerlandson',
#      'isic_to_sector',
#      'naics_isic_sic',
#      'naics_sic_crosswalk',
#      'naics_sic_data',
#      'net_plant_balance',
#      'operations_emissions_by_fuel',
#      'operations_emissions_by_tech',
#      'other_generation',
#      'pcaf_wdi_gdp',
#      'portfolio_universe',
#      'positions',
#      'power_plant_list',
#      'power_plants_list',
#      'pp_list',
#      'pp_list__dbt_tmp',
#      'revenue_by_tech',
#      'sample_itr',
#      'sf_test',
#      'sfi_cement',
#      'sfi_steel',
#      'sic_isic',
#      'state_policies',
#      'state_targets',
#      'subdivisions',
#      't_a',
#      't_c',
#      't_d',
#      't_f',
#      't_i',
#      't_r',
#      'ticker',
#      'trino_batch_insert_test',
#      'trino_iceberg_demo',
#      'utility_information',
#      'utility_state_map']},
#    {'schema': 'wri_gppd',
#     'tables': ['gppd_power_plants_list', 'gppd_source']}]},
#  {'catalog': 'osc_datacommons_hive_ingest',
#   'schemas': [{'schema': 'aicoe_osc_demo_results', 'tables': ['infer_kpi']},
#    {'schema': 'default', 'tables': []},
#    {'schema': 'demo_dv',
#     'tables': ['itr_benchmark_ei',
#      'itr_benchmark_prod',
#      'itr_company_data',
#      'itr_cumulative_budgets',
#      'itr_cumulative_emissions',
#      'itr_overshoot_ratios',
#      'itr_production_data',
#      'itr_target_data',
#      'itr_temperature_scores',
#      'itr_trajectory_data']},
#    {'schema': 'dera',
#     'tables': ['assets_usd_by_lei',
#      'assets_xyz_by_lei',
#      'average_fx',
#      'cash_usd_by_lei',
#      'cash_xyz_by_lei',
#      'closing_fx',
#      'debt_usd_by_lei',
#      'debt_xyz_by_lei',
#      'dera_num',
#      'dera_num_source',
#      'dera_sub',
#      'dera_sub_source',
#      'dera_tag',
#      'dera_tag_source',
#      'financials_by_lei',
#      'float_usd_by_lei',
#      'float_xyz_by_lei',
#      'fy_income_usd_by_lei',
#      'fy_income_xyz_by_lei',
#      'fy_revenue_usd_by_lei',
#      'fy_revenue_xyz_by_lei',
#      'sic_isic',
#      't_a',
#      't_c',
#      't_d',
#      't_f',
#      't_i',
#      't_r',
#      'ticker',
#      'ticker_source']},
#    {'schema': 'essd',
#     'tables': ['ch4_gwp',
#      'ch4_gwp_source',
#      'ghg_data',
#      'ghg_data_source',
#      'gwp100_data',
#      'gwp100_data_source',
#      'gwp_100yr',
#      'gwp_100yr_source',
#      'lulucf',
#      'lulucf_source',
#      'regions',
#      'regions_source',
#      'sectors',
#      'sectors_source']},
#    {'schema': 'iceberg_demo', 'tables': []},
#    {'schema': 'information_schema',
#     'tables': ['applicable_roles',
#      'columns',
#      'enabled_roles',
#      'roles',
#      'schemata',
#      'table_privileges',
#      'tables',
#      'views']},
#    {'schema': 'ingest', 'tables': []},
#    {'schema': 'mdt_sandbox',
#     'tables': ['countries',
#      'isic_to_sector',
#      'itr_portfolio_universe',
#      'pcaf_dbt_models',
#      'portfolio_universe',
#      'saved_queries',
#      'sf_oecd_exch_rates',
#      'sf_oecd_exch_rates_source',
#      'sf_oecd_exgr_dco2',
#      'sf_oecd_exgr_dco2_source',
#      'sf_oecd_imgr_fco2',
#      'sf_oecd_imgr_fco2_source',
#      'sf_primap_hist_emissions',
#      'sf_primap_hist_emissions_source',
#      'sf_total_sovereign_emissions',
#      'sf_total_sovereign_emissions_source',
#      'sf_unfccc_countries_source',
#      'sf_unfccc_results',
#      'sf_unfccc_results_source',
#      'sf_unfccc_with_lulucf',
#      'sf_unfccc_with_lulucf_source',
#      'sf_unfccc_without_lulucf',
#      'sf_unfccc_without_lulucf_source',
#      'sf_wdi_gdp',
#      'sf_wdi_gdp_source',
#      'sf_wdi_population',
#      'sf_wdi_population_source',
#      'subdivisions']},
#    {'schema': 'pcaf_sovereign_footprint',
#     'tables': ['oecd_co2_emissions',
#      'population_source',
#      'sf_oecd_exch_rates',
#      'sf_oecd_exgr_dco2',
#      'sf_oecd_imgr_fco2',
#      'sf_primap_emissions_with_lulucf',
#      'sf_primap_emissions_without_lulucf',
#      'sf_total_sovereign_emissions',
#      'sf_unfccc_countries',
#      'sf_unfccc_results',
#      'sf_unfccc_with_lulucf',
#      'sf_unfccc_without_lulucf',
#      'sf_wdi_gdp',
#      'sf_wdi_population']},
#    {'schema': 'rmi',
#     'tables': ['assets_earnings_investments',
#      'assets_earnings_investments_source',
#      'customers_sales',
#      'customers_sales_source',
#      'debt_equity_returns',
#      'debt_equity_returns_source',
#      'emissions_targets',
#      'emissions_targets_source',
#      'employees',
#      'employees_source',
#      'expenditure_bills_burden',
#      'expenditure_bills_burden_source',
#      'housing_units_income',
#      'housing_units_income_source',
#      'net_plant_balance',
#      'net_plant_balance_source',
#      'operations_emissions_by_fuel',
#      'operations_emissions_by_fuel_source',
#      'operations_emissions_by_tech',
#      'operations_emissions_by_tech_source',
#      'revenue_by_tech',
#      'revenue_by_tech_source',
#      'state_policies',
#      'state_policies_source',
#      'state_targets',
#      'state_targets_source',
#      'utility_information',
#      'utility_information_2023',
#      'utility_information_2023_source',
#      'utility_information_source',
#      'utility_state_map',
#      'utility_state_map_2023',
#      'utility_state_map_2023_source',
#      'utility_state_map_source']},
#    {'schema': 'sandbox',
#     'tables': ['assets_earnings_investments',
#      'assets_usd_by_lei',
#      'assets_xyz_by_lei',
#      'average_fx',
#      'cash_usd_by_lei',
#      'cash_xyz_by_lei',
#      'census_all_sector_survey_2017',
#      'census_sic4',
#      'census_sic_ranges',
#      'climactor_demo',
#      'closing_fx',
#      'countries',
#      'customers_sales',
#      'dashboard_carbon_intensity',
#      'dashboard_carbon_monitoring',
#      'dashboard_pod_energy',
#      'debt_equity_returns',
#      'debt_usd_by_lei',
#      'debt_xyz_by_lei',
#      'dera_num',
#      'dera_sub',
#      'dera_tag',
#      'emissions_targets',
#      'employees',
#      'epa_co2_injection',
#      'epa_direct_emitters',
#      'epa_gathering_boosting',
#      'epa_geologic_sequestration_of_co2',
#      'epa_ldc_direct_emissions',
#      'epa_onshore_oil_gas_prod',
#      'epa_parent_attribution',
#      'epa_parent_company',
#      'epa_sankey',
#      'epa_sf6_from_elec_equip',
#      'epa_suppliers',
#      'epa_transmission_pipelines',
#      'essd_ch4_gwp',
#      'essd_ghg_data',
#      'essd_gwp100_data',
#      'essd_gwp_100yr',
#      'essd_lulucf',
#      'essd_regions',
#      'essd_sectors',
#      'expenditure_bills_burden',
#      'financials_by_lei',
#      'float_usd_by_lei',
#      'float_xyz_by_lei',
#      'fy_income_usd_by_lei',
#      'fy_income_xyz_by_lei',
#      'fy_revenue_usd_by_lei',
#      'fy_revenue_xyz_by_lei',
#      'gleif_direct_issuer_ultimate_issuer',
#      'gleif_isin_lei',
#      'gppd',
#      'gppd_plants',
#      'gppd_plants_list',
#      'gppd_power_plants_list',
#      'gppd_pp_list',
#      'gppd_source',
#      'housing_units_income',
#      'iceberg_demo_erikerlandson',
#      'isic_to_sector',
#      'naics_isic_sic',
#      'naics_sic_crosswalk',
#      'naics_sic_data',
#      'net_plant_balance',
#      'operations_emissions_by_fuel',
#      'operations_emissions_by_tech',
#      'other_generation',
#      'pcaf_wdi_gdp',
#      'portfolio_universe',
#      'positions',
#      'power_plant_list',
#      'power_plants_list',
#      'pp_list',
#      'pp_list__dbt_tmp',
#      'revenue_by_tech',
#      'sample_itr',
#      'sf_test',
#      'sfi_cement',
#      'sfi_steel',
#      'sic_isic',
#      'state_policies',
#      'state_targets',
#      'subdivisions',
#      't_a',
#      't_c',
#      't_d',
#      't_f',
#      't_i',
#      't_r',
#      'ticker',
#      'trino_batch_insert_test',
#      'trino_iceberg_demo',
#      'utility_information',
#      'utility_state_map']},
#    {'schema': 'wri_gppd',
#     'tables': ['gppd_power_plants_list', 'gppd_source']}]},
#  {'catalog': 'system',
#   'schemas': [{'schema': 'information_schema',
#     'tables': ['applicable_roles',
#      'columns',
#      'enabled_roles',
#      'roles',
#      'schemata',
#      'table_privileges',
#      'tables',
#      'views']},
#    {'schema': 'jdbc',
#     'tables': ['attributes',
#      'catalogs',
#      'columns',
#      'procedure_columns',
#      'procedures',
#      'pseudo_columns',
#      'schemas',
#      'super_tables',
#      'super_types',
#      'table_types',
#      'tables',
#      'types',
#      'udts']},
#    {'schema': 'metadata',
#     'tables': ['analyze_properties',
#      'catalogs',
#      'column_properties',
#      'materialized_view_properties',
#      'materialized_views',
#      'schema_properties',
#      'table_comments',
#      'table_properties']},
#    {'schema': 'runtime',
#     'tables': ['nodes',
#      'optimizer_rule_stats',
#      'queries',
#      'tasks',
#      'transactions']}]},
#  {'catalog': 'uwm_prometheus',
#   'schemas': [{'schema': 'default', 'tables': []},
#    {'schema': 'information_schema',
#     'tables': ['applicable_roles',
#      'columns',
#      'enabled_roles',
#      'roles',
#      'schemata',
#      'table_privileges',
#      'tables',
#      'views']}]}]

# %%
import json

# Specify the file path
file_path = '../data/data_commons/trino_catalog_schema_table.json'

# Write the JSON data to a file
with open(file_path, 'w') as file:
    json.dump(all_data, file, indent=4)

# %%
# CNAME is Catalog Name (osc_datacommons_dev)
# SNAME is Schema Name (wri_gppd)
# TNAME is Table Name (plants)

import os
import pandas as pd
from pathlib import Path

def trino_to_df(cname, sname, tname):
    trino_table = '.'.join([cname, sname, tname])
    cur.execute('show columns from ' + trino_table)
    columns_df = pd.DataFrame(cur.fetchall()).dropna(axis=1,how='all')
    
    cur.execute('select * from ' + trino_table)
    df = pd.DataFrame(cur.fetchall())
    df.columns = columns_df.iloc[:, 0]
    return df

# Function to save DataFrame to CSV
def save_df_to_csv(df, cname, sname, tname):
    # Adjust the base directory to a writable path in this environment
    base_dir = '../data/data_commons'
    dir_path = os.path.join(base_dir, cname, sname)
    
    # Ensure the directory exists
    Path(dir_path).mkdir(parents=True, exist_ok=True)
    
    # Define the full file path
    file_path = os.path.join(dir_path, f'{tname}.csv')
    
    # Save the DataFrame to CSV
    df.to_csv(file_path, index=False)
    print(f'Saved to {file_path}')

# %% [markdown]
# # Saving all tables with 'emissions' in it

# %%
# Iterate over all_data
for catalog_data in all_data:
    cname = catalog_data['catalog']
    for schema_data in catalog_data['schemas']:
        sname = schema_data['schema']
        for tname in schema_data['tables']:
            if 'emission' in tname:
                try:
                    df = trino_to_df(cname, sname, tname)
                    # Adjust the path as necessary for your environment
                    save_df_to_csv(df, cname, sname, tname)
                except Exception as e:
                    print(f'Error processing {cname}.{sname}.{tname}: {e}')
# Out:
# Saved to ../data/data_commons/osc_datacommons_dev/demo_dv/itr_cumulative_emissions.csv
# Saved to ../data/data_commons/osc_datacommons_dev/mdt_sandbox/sf_primap_hist_emissions.csv
# Saved to ../data/data_commons/osc_datacommons_dev/mdt_sandbox/sf_primap_hist_emissions_source.csv
# Saved to ../data/data_commons/osc_datacommons_dev/mdt_sandbox/sf_total_sovereign_emissions.csv
# Saved to ../data/data_commons/osc_datacommons_dev/mdt_sandbox/sf_total_sovereign_emissions_source.csv
# Saved to ../data/data_commons/osc_datacommons_dev/pcaf_sovereign_footprint/oecd_co2_emissions.csv
# Saved to ../data/data_commons/osc_datacommons_dev/pcaf_sovereign_footprint/sf_primap_emissions_with_lulucf.csv
# Saved to ../data/data_commons/osc_datacommons_dev/pcaf_sovereign_footprint/sf_primap_emissions_without_lulucf.csv
# Saved to ../data/data_commons/osc_datacommons_dev/pcaf_sovereign_footprint/sf_total_sovereign_emissions.csv
# Saved to ../data/data_commons/osc_datacommons_dev/rmi/emissions_targets.csv
# Saved to ../data/data_commons/osc_datacommons_dev/rmi/emissions_targets_source.csv
# Saved to ../data/data_commons/osc_datacommons_dev/rmi/operations_emissions_by_fuel.csv
# Saved to ../data/data_commons/osc_datacommons_dev/rmi/operations_emissions_by_fuel_source.csv
# Saved to ../data/data_commons/osc_datacommons_dev/rmi/operations_emissions_by_tech.csv
# Saved to ../data/data_commons/osc_datacommons_dev/rmi/operations_emissions_by_tech_source.csv
# Saved to ../data/data_commons/osc_datacommons_dev/sandbox/emissions_targets.csv
# Saved to ../data/data_commons/osc_datacommons_dev/sandbox/epa_ldc_direct_emissions.csv
# Saved to ../data/data_commons/osc_datacommons_dev/sandbox/operations_emissions_by_fuel.csv
# Saved to ../data/data_commons/osc_datacommons_dev/sandbox/operations_emissions_by_tech.csv
# Error processing osc_datacommons_hive_ingest.demo_dv.itr_cumulative_emissions: TrinoExternalError(type=EXTERNAL, name=UNSUPPORTED_TABLE_TYPE, message="Cannot query Iceberg table 'demo_dv.itr_cumulative_emissions'", query_id=20240404_191538_00488_xvsm6)
# Saved to ../data/data_commons/osc_datacommons_hive_ingest/mdt_sandbox/sf_primap_hist_emissions.csv
# Error processing osc_datacommons_hive_ingest.mdt_sandbox.sf_primap_hist_emissions_source: TrinoExternalError(type=EXTERNAL, name=UNSUPPORTED_TABLE_TYPE, message="Cannot query Iceberg table 'mdt_sandbox.sf_primap_hist_emissions_source'", query_id=20240404_191540_00491_xvsm6)
# Saved to ../data/data_commons/osc_datacommons_hive_ingest/mdt_sandbox/sf_total_sovereign_emissions.csv
# Error processing osc_datacommons_hive_ingest.mdt_sandbox.sf_total_sovereign_emissions_source: TrinoExternalError(type=EXTERNAL, name=UNSUPPORTED_TABLE_TYPE, message="Cannot query Iceberg table 'mdt_sandbox.sf_total_sovereign_emissions_source'", query_id=20240404_191542_00494_xvsm6)
# Error processing osc_datacommons_hive_ingest.pcaf_sovereign_footprint.oecd_co2_emissions: TrinoExternalError(type=EXTERNAL, name=UNSUPPORTED_TABLE_TYPE, message="Cannot query Iceberg table 'pcaf_sovereign_footprint.oecd_co2_emissions'", query_id=20240404_191542_00495_xvsm6)
# Error processing osc_datacommons_hive_ingest.pcaf_sovereign_footprint.sf_primap_emissions_with_lulucf: TrinoExternalError(type=EXTERNAL, name=UNSUPPORTED_TABLE_TYPE, message="Cannot query Iceberg table 'pcaf_sovereign_footprint.sf_primap_emissions_with_lulucf'", query_id=20240404_191543_00496_xvsm6)
# Error processing osc_datacommons_hive_ingest.pcaf_sovereign_footprint.sf_primap_emissions_without_lulucf: TrinoExternalError(type=EXTERNAL, name=UNSUPPORTED_TABLE_TYPE, message="Cannot query Iceberg table 'pcaf_sovereign_footprint.sf_primap_emissions_without_lulucf'", query_id=20240404_191543_00497_xvsm6)
# Error processing osc_datacommons_hive_ingest.pcaf_sovereign_footprint.sf_total_sovereign_emissions: TrinoExternalError(type=EXTERNAL, name=UNSUPPORTED_TABLE_TYPE, message="Cannot query Iceberg table 'pcaf_sovereign_footprint.sf_total_sovereign_emissions'", query_id=20240404_191543_00498_xvsm6)
# Saved to ../data/data_commons/osc_datacommons_hive_ingest/rmi/emissions_targets.csv
# Error processing osc_datacommons_hive_ingest.rmi.emissions_targets_source: TrinoExternalError(type=EXTERNAL, name=UNSUPPORTED_TABLE_TYPE, message="Cannot query Iceberg table 'rmi.emissions_targets_source'", query_id=20240404_191546_00501_xvsm6)
# Saved to ../data/data_commons/osc_datacommons_hive_ingest/rmi/operations_emissions_by_fuel.csv
# Error processing osc_datacommons_hive_ingest.rmi.operations_emissions_by_fuel_source: TrinoExternalError(type=EXTERNAL, name=UNSUPPORTED_TABLE_TYPE, message="Cannot query Iceberg table 'rmi.operations_emissions_by_fuel_source'", query_id=20240404_191641_00504_xvsm6)
# Saved to ../data/data_commons/osc_datacommons_hive_ingest/rmi/operations_emissions_by_tech.csv
# Error processing osc_datacommons_hive_ingest.rmi.operations_emissions_by_tech_source: TrinoExternalError(type=EXTERNAL, name=UNSUPPORTED_TABLE_TYPE, message="Cannot query Iceberg table 'rmi.operations_emissions_by_tech_source'", query_id=20240404_191720_00507_xvsm6)
# Error processing osc_datacommons_hive_ingest.sandbox.emissions_targets: TrinoExternalError(type=EXTERNAL, name=UNSUPPORTED_TABLE_TYPE, message="Cannot query Iceberg table 'sandbox.emissions_targets'", query_id=20240404_191720_00508_xvsm6)
# Error processing osc_datacommons_hive_ingest.sandbox.epa_ldc_direct_emissions: TrinoExternalError(type=EXTERNAL, name=UNSUPPORTED_TABLE_TYPE, message="Cannot query Iceberg table 'sandbox.epa_ldc_direct_emissions'", query_id=20240404_191720_00509_xvsm6)
# Error processing osc_datacommons_hive_ingest.sandbox.operations_emissions_by_fuel: TrinoExternalError(type=EXTERNAL, name=UNSUPPORTED_TABLE_TYPE, message="Cannot query Iceberg table 'sandbox.operations_emissions_by_fuel'", query_id=20240404_191721_00510_xvsm6)
# Error processing osc_datacommons_hive_ingest.sandbox.operations_emissions_by_tech: TrinoExternalError(type=EXTERNAL, name=UNSUPPORTED_TABLE_TYPE, message="Cannot query Iceberg table 'sandbox.operations_emissions_by_tech'", query_id=20240404_191721_00511_xvsm6)
